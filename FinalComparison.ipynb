# %%
import pandas as pd
path = f"./0_gen_tc_supercon/tinyllama-chat_generated_samples_updated.csv"
df = pd.read_csv(path)

# %%
import pandas as pd
# Read the files
fourbit_models = [
        "unsloth/tinyllama-chat", #X
        "unsloth/mistral-7b-bnb-4bit", #X
        "unsloth/gemma-7b-bnb-4bit", #X
        "unsloth/llama-3-8b-bnb-4bit", #X 
]  # More models at https://huggingface.co/unsloth

# %% [markdown]
# # TC_ SUPERCON

# %%
for idx, name in enumerate(fourbit_models):

        #Read the model
        fourbit_model = fourbit_models[idx]
        path = f"./0_gen_tc_supercon/{fourbit_model.split('/')[1]}_generated_samples_updated.csv"
        df = pd.read_csv(path)
        print("********", name)

        num_samples = df.shape[0]
        print("Number of Samples", num_samples)

        nans = df['rms_dist'].isna().sum()

        print("*Number of NANs in rms_dist", nans)

        print("*NANs ratio rms_dist", nans/num_samples)

        print("*Mean Rms_dist", df['rms_dist'].sum()/(num_samples-nans))

        df["result"] = abs(df['out_data_pred'] - df['orj_prop_val'])

        nan_alignn = df['result'].isna().sum()

        print("***NANs Ratio in Result", (nan_alignn/num_samples))

        print("***Mean Eror Ratio", df["result"].sum()/(num_samples - nan_alignn))

        print("***********")
# Out:
# ******** unsloth/tinyllama-chat
# Number of Samples 106
# *Number of NANs in rms_dist 66
# *NANs ratio rms_dist 0.6226415094339622
# *Mean Rms_dist 0.046856731541458564
# ***NANs Ratio in Result 0.0660377358490566
# ***Mean Eror Ratio 2.6349334810096208
# ***********
# ******** unsloth/mistral-7b-bnb-4bit
# Number of Samples 106
# *Number of NANs in rms_dist 39
# *NANs ratio rms_dist 0.36792452830188677
# *Mean Rms_dist 0.03551873254469093
# ***NANs Ratio in Result 0.009433962264150943
# ***Mean Eror Ratio 2.0622375903702914
# ***********
# ******** unsloth/gemma-7b-bnb-4bit
# Number of Samples 106
# *Number of NANs in rms_dist 41
# *NANs ratio rms_dist 0.3867924528301887
# *Mean Rms_dist 0.025489942181502932
# ***NANs Ratio in Result 0.0
# ***Mean Eror Ratio 2.0928452556930344
# ***********
# ******** unsloth/llama-3-8b-bnb-4bit
# Number of Samples 106
# *Number of NANs in rms_dist 46
# *NANs ratio rms_dist 0.4339622641509434
# *Mean Rms_dist 0.03792288432685142
# ***NANs Ratio in Result 0.03773584905660377
# ***Mean Eror Ratio 2.5002729941103974
# ***********

# %% [markdown]
# # OPTB88bvdw Bandgap

# %%
for idx, name in enumerate(fourbit_models):

        #Read the model
        fourbit_model = fourbit_models[idx]
        path = f"./1_gen_optb88vdw_bandgap/{fourbit_model.split('/')[1]}_generated_samples_updated.csv"
        df = pd.read_csv(path)
        print("********", name)

        num_samples = 300
        print("Number of Samples", num_samples)

        nans = df.iloc[:300]['rms_dist'].isna().sum()

        print("*Number of NANs in rms_dist", nans)

        print("*NANs ratio rms_dist", nans/num_samples)

        print("*Mean Rms_dist", df.iloc[:300]['rms_dist'].sum()/(num_samples-nans))

        df["result"] = abs(df['out_data_pred'] - df['orj_prop_val'])

        nan_alignn = df.iloc[:300]['result'].isna().sum()

        print("***NANs Ratio in Result", (nan_alignn/num_samples))

        print("***Mean Eror Ratio", df.iloc[:300]["result"].sum()/(num_samples - nan_alignn))

        print("***********")
# Out:
# ******** unsloth/tinyllama-chat
# Number of Samples 300
# *Number of NANs in rms_dist 232
# *NANs ratio rms_dist 0.7733333333333333
# *Mean Rms_dist 0.11355528878025228
# ***NANs Ratio in Result 0.12666666666666668
# ***Mean Eror Ratio 1.331762424442718
# ***********
# ******** unsloth/mistral-7b-bnb-4bit
# Number of Samples 300
# *Number of NANs in rms_dist 194
# *NANs ratio rms_dist 0.6466666666666666
# *Mean Rms_dist 0.09384297156549076
# ***NANs Ratio in Result 0.02
# ***Mean Eror Ratio 0.958109207056615
# ***********
# ******** unsloth/gemma-7b-bnb-4bit
# Number of Samples 300
# *Number of NANs in rms_dist 201
# *NANs ratio rms_dist 0.67
# *Mean Rms_dist 0.08201581658121947
# ***NANs Ratio in Result 0.023333333333333334
# ***Mean Eror Ratio 1.0104898913498626
# ***********
# ******** unsloth/llama-3-8b-bnb-4bit
# Number of Samples 300
# *Number of NANs in rms_dist 207
# *NANs ratio rms_dist 0.69
# *Mean Rms_dist 0.09882020531768979
# ***NANs Ratio in Result 0.05
# ***Mean Eror Ratio 0.9530947323832595
# ***********

# %% [markdown]
# # Mbj_bandgap

# %%
for idx, name in enumerate(fourbit_models):

        #Read the model
        fourbit_model = fourbit_models[idx]
        path = f"./2_gen_mbj_bandgap/{fourbit_model.split('/')[1]}_generated_samples_updated.csv"
        df = pd.read_csv(path)
        print("********", name)

        num_samples = 300
        print("Number of Samples", num_samples)

        nans = df.iloc[:300]['rms_dist'].isna().sum()

        print("*Number of NANs in rms_dist", nans)

        print("*NANs ratio rms_dist", nans/num_samples)

        print("*Mean Rms_dist", df.iloc[:300]['rms_dist'].sum()/(num_samples-nans))

        df["result"] = abs(df['out_data_pred'] - df['orj_prop_val'])

        nan_alignn = df.iloc[:300]['result'].isna().sum()

        print("***NANs Ratio in Result", (nan_alignn/num_samples))

        print("***Mean Eror Ratio", df.iloc[:300]["result"].sum()/(num_samples - nan_alignn))

        print("***********")
# Out:
# ******** unsloth/tinyllama-chat
# Number of Samples 300
# *Number of NANs in rms_dist 191
# *NANs ratio rms_dist 0.6366666666666667
# *Mean Rms_dist 0.06443636509077681
# ***NANs Ratio in Result 0.05333333333333334
# ***Mean Eror Ratio 0.7416355206535107
# ***********
# ******** unsloth/mistral-7b-bnb-4bit
# Number of Samples 300
# *Number of NANs in rms_dist 164
# *NANs ratio rms_dist 0.5466666666666666
# *Mean Rms_dist 0.06087542118053184
# ***NANs Ratio in Result 0.16333333333333333
# ***Mean Eror Ratio 0.5645862474130444
# ***********
# ******** unsloth/gemma-7b-bnb-4bit
# Number of Samples 300
# *Number of NANs in rms_dist 168
# *NANs ratio rms_dist 0.56
# *Mean Rms_dist 0.038757850611174566
# ***NANs Ratio in Result 0.0033333333333333335
# ***Mean Eror Ratio 0.5352215424556795
# ***********
# ******** unsloth/llama-3-8b-bnb-4bit
# Number of Samples 300
# *Number of NANs in rms_dist 164
# *NANs ratio rms_dist 0.5466666666666666
# *Mean Rms_dist 0.06286265163382607
# ***NANs Ratio in Result 0.016666666666666666
# ***Mean Eror Ratio 0.5827222467661914
# ***********
