# %%
from jarvis.db.jsonutils import loadjson, dumpjson
import matplotlib.pyplot as plt
import os

# %%
#Saving Figures
#fig.savefig(img_name, dpi=500)

# %% [markdown]
# # TC_Supercon

# %%
path = "./0_results_tc_supercon"

# %%
models = {}
for cls in os.listdir(path):
    if (not cls.startswith('.')) and ("log_history" in cls):
        data = loadjson(os.path.join(path, cls))
        models[cls.split("_")[0]] = (data[-1]["train_runtime"], data[-1]["train_samples_per_second"])   

fig, ax = plt.subplots(figsize=(12, 6))

for idx, name in enumerate(models):
    bar = plt.bar(name, models[name][0]/60)
    ax.bar_label(bar)
    
class_names = list(models.keys())
plt.xticks([])  # This removes the x-axis labels

plt.legend(class_names,loc = 2)
plt.title('Training Time of LLMs')
plt.xlabel('LLM Models')
plt.ylabel('Time Spent in minutes')
plt.show()


fig, ax = plt.subplots(figsize=(12, 6))

for idx, name in enumerate(models):
    bar = plt.bar(name, models[name][1])
    ax.bar_label(bar)
    
class_names = list(models.keys())
plt.xticks([])  # This removes the x-axis labels

plt.legend(class_names,loc = 2)
plt.title('Training Time of LLMs')
plt.xlabel('LLM Models')
plt.ylabel('Time Spent in minutes')
plt.title('Number of Sample being Trained per second')
plt.xlabel('LLM Models')
plt.ylabel('# of Sample')
# Out:
# Text(0, 0.5, '# of Sample')

# %%
models = {}
for cls in os.listdir(path):
    if (not cls.startswith('.')) and ("log_history" in cls):
            data = [values.get('loss') for values in loadjson(os.path.join(path, cls))], [values.get('epoch') for values in loadjson(os.path.join(path, cls))]
            models[cls.split("_")[0]] = data


import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi =500)
plt.title('Training Loss Graph of LLM Models')
for idx, name in enumerate(models):
    plt.plot(models[name][1], models[name][0])
    

plt.xlabel("Epoch")
plt.ylabel("Loss Value")
plt.xlim(0, 8)  # Show only the x range from 2 to 8
class_names = list(models.keys())

plt.legend(class_names,loc = 1)

# %% [markdown]
# # OPTB88bvdw Bandgap

# %%
path = "./1_results_optb88vdw_bandgap"

# %%
models = {}
for cls in os.listdir(path):
    if (not cls.startswith('.')) and ("log_history" in cls):
        data = loadjson(os.path.join(path, cls))
        models[cls.split("_")[0]] = (data[-1]["train_runtime"], data[-1]["train_samples_per_second"])   

fig, ax = plt.subplots(figsize=(10, 6))

for idx, name in enumerate(models):
    bar = plt.bar(name, models[name][0]/60)
    ax.bar_label(bar)
    
class_names = list(models.keys())
plt.xticks([])  # This removes the x-axis labels

plt.legend(class_names,loc = 2)
plt.title('Training Time of LLMs')
plt.xlabel('LLM Models')
plt.ylabel('Time Spent in minutes')
plt.show()


fig, ax = plt.subplots(figsize=(10, 6))

for idx, name in enumerate(models):
    bar = plt.bar(name, models[name][1])
    ax.bar_label(bar)
    
class_names = list(models.keys())
plt.xticks([])  # This removes the x-axis labels

plt.legend(class_names,loc = 2)
plt.title('Training Time of LLMs')
plt.xlabel('LLM Models')
plt.ylabel('Time Spent in minutes')
plt.title('Number of Sample being Trained per second')
plt.xlabel('LLM Models')
plt.ylabel('# of Sample')
# Out:
# Text(0, 0.5, '# of Sample')

# %%
models = {}
for cls in os.listdir(path):
    if (not cls.startswith('.')) and ("log_history" in cls):
            data = [values.get('loss') for values in loadjson(os.path.join(path, cls))], [values.get('epoch') for values in loadjson(os.path.join(path, cls))]
            models[cls.split("_")[0]] = data


import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi =500)
plt.title('Training Loss Graph of LLM Models')
for idx, name in enumerate(models):
    plt.plot(models[name][1], models[name][0])
    

plt.xlabel("Epoch")
plt.ylabel("Loss Value")
plt.xlim(0, 8)  # Show only the x range from 2 to 8
class_names = list(models.keys())

plt.legend(class_names,loc = 1)

# %% [markdown]
# # Mbj_bandgap

# %%
path = "./2_results_mbj_bandgap"

# %%
models = {}
for cls in os.listdir(path):
    if (not cls.startswith('.')) and ("log_history" in cls):
        data = loadjson(os.path.join(path, cls))
        models[cls.split("_")[0]] = (data[-1]["train_runtime"], data[-1]["train_samples_per_second"])   

fig, ax = plt.subplots(figsize=(10, 6))

for idx, name in enumerate(models):
    bar = plt.bar(name, models[name][0]/60)
    ax.bar_label(bar)
    
class_names = list(models.keys())
plt.xticks([])  # This removes the x-axis labels

plt.legend(class_names,loc = 2)
plt.title('Training Time of LLMs')
plt.xlabel('LLM Models')
plt.ylabel('Time Spent in minutes')
plt.show()


fig, ax = plt.subplots(figsize=(10, 6))

for idx, name in enumerate(models):
    bar = plt.bar(name, models[name][1])
    ax.bar_label(bar)
    
class_names = list(models.keys())
plt.xticks([])  # This removes the x-axis labels

plt.legend(class_names,loc = 2)
plt.title('Training Time of LLMs')
plt.xlabel('LLM Models')
plt.ylabel('Time Spent in minutes')
plt.title('Number of Sample being Trained per second')
plt.xlabel('LLM Models')
plt.ylabel('# of Sample')
# Out:
# Text(0, 0.5, '# of Sample')

# %%
models = {}
for cls in os.listdir(path):
    if (not cls.startswith('.')) and ("log_history" in cls):
            data = [values.get('loss') for values in loadjson(os.path.join(path, cls))], [values.get('epoch') for values in loadjson(os.path.join(path, cls))]
            models[cls.split("_")[0]] = data


import matplotlib.pyplot as plt
plt.figure(figsize=(10,6),dpi =500)
plt.title('Training Loss Graph of LLM Models')
for idx, name in enumerate(models):
    plt.plot(models[name][1], models[name][0])
    

plt.xlabel("Epoch")
plt.ylabel("Loss Value")
plt.xlim(0, 8)  # Show only the x range from 2 to 8
class_names = list(models.keys())

plt.legend(class_names,loc = 1)

# %% [markdown]
# # Time Comparison in the inference

# %%
from models import load_model, get_model, get_trainer, save_model
import os
from unsloth import FastLanguageModel
from datasets import load_dataset
import pandas as pd 
from utils import eval_prompts
from sample_funcs import parse_fn
from transformers import TextStreamer
import time
import random
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
fourbit_models = [
        "unsloth/tinyllama-chat", #X
        "unsloth/mistral-7b-bnb-4bit", #X
        "unsloth/gemma-7b-bnb-4bit", #X
        "unsloth/llama-3-8b-bnb-4bit", #X 
]  # More models at https://huggingface.co/unsloth

def path_(path): 
        
        for model_idx, models in enumerate(fourbit_models):
                
                # LLM Models
                fourbit_model = fourbit_models[model_idx]   
                print("Models Name", fourbit_model)
                llm_model, llm_tokenizer = FastLanguageModel.from_pretrained(os.path.join(path, fourbit_model.split("/")[1])) 
                FastLanguageModel.for_inference(llm_model)  # Enable native 2x faster inference

                # Data Loading
            
                if path == "./0_models_tc_supercon":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "Tc_supercon" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                if path == "./1_models_optb88vdw_bandgap":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "optb88vdw_bandgap" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                if path == "./2_models_mbj_bandgap":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "mbj_bandgap" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                
                data_test = data_test.add_column("prompt", eval_prompts(data_test))


                # LLM OUTPUT GENERATION
                
                start = time.time()

                random_samples = random.sample(data_test["prompt"], 20)
                
                for idx, prompt in enumerate(random_samples):

                # for idx, prompt in enumerate(data_test["prompt"][:20]):

                        batch = llm_tokenizer(prompt, return_tensors="pt")
                        batch = {k: v.cuda() for k, v in batch.items()}
                        generate_ids = llm_model.generate(
                                    **batch,
                                    do_sample=False,
                                    max_new_tokens=4096,
                                    pad_token_id=llm_tokenizer.eos_token_id,
                                    use_cache=True)

                        gen_strs = llm_tokenizer.batch_decode(
                                    generate_ids, 
                                    skip_special_tokens=True, 
                                    clean_up_tokenization_spaces=True
                                    )
                end = time.time()
                print('Elapsed time is %f seconds for 20 samples, avearaged %f' % (end-start,(end-start)/20))

print("\n\nTC Supercon**************")
path_("./0_models_tc_supercon")  
print("OPTB88")
path_("./1_models_optb88vdw_bandgap")   
print("MBJ_BANDGAP")
path_("./2_models_mbj_bandgap")
# Out:
# TC Supercon**************
# Models Name unsloth/tinyllama-chat
# ==((====))==  Unsloth 2024.10.7: Fast Llama patching. Transformers = 4.44.2.
#    \\   /|    GPU: Quadro RTX 8000. Max memory: 44.481 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.0+cu124. CUDA = 7.5. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post2. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: We fixed a gradient accumulation bug, but it seems like you don't have the latest transformers version!
# Please update transformers, TRL and unsloth via:
# `pip install --upgrade --no-cache-dir unsloth git+https://github.com/huggingface/transformers.git git+https://github.com/huggingface/trl.git`
# Unsloth 2024.10.7 patched 22 layers with 22 QKV layers, 22 O layers and 22 MLP layers.

# %%
# Fixed prompt

fourbit_models = [
        "unsloth/tinyllama-chat", #X
        "unsloth/mistral-7b-bnb-4bit", #X
        "unsloth/gemma-7b-bnb-4bit", #X
        "unsloth/llama-3-8b-bnb-4bit", #X 
]  # More models at https://huggingface.co/unsloth

def path_(path): 
        
        for model_idx, models in enumerate(fourbit_models):
                
                # LLM Models
                fourbit_model = fourbit_models[model_idx]   
                print("Models Name", fourbit_model)
                llm_model, llm_tokenizer = FastLanguageModel.from_pretrained(os.path.join(path, fourbit_model.split("/")[1])) 
                FastLanguageModel.for_inference(llm_model)  # Enable native 2x faster inference

                # Data Loading
            
                if path == "./0_models_tc_supercon":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "Tc_supercon" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                if path == "./1_models_optb88vdw_bandgap":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "optb88vdw_bandgap" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                if path == "./2_models_mbj_bandgap":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "mbj_bandgap" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                
                data_test = data_test.add_column("prompt", eval_prompts(data_test))


                # LLM OUTPUT GENERATION
                
                start = time.time()

                sample = "Below is a description of a superconductor material. Write a response that appropriately completes the request.\n\n### Instruction:\nGenerate atomic structure description with lattice lengths, angles, coordinates and atom types.\n\n### Input:\nThe chemical formula is ScZnRh2.\n\n### Response:\n"

                for idx in range(20):

                # for idx, prompt in enumerate(data_test["prompt"][:20]):

                        batch = llm_tokenizer(sample, return_tensors="pt")
                        batch = {k: v.cuda() for k, v in batch.items()}
                        generate_ids = llm_model.generate(
                                    **batch,
                                    do_sample=False,
                                    max_new_tokens=4096,
                                    pad_token_id=llm_tokenizer.eos_token_id,
                                    use_cache=True)

                        gen_strs = llm_tokenizer.batch_decode(
                                    generate_ids, 
                                    skip_special_tokens=True, 
                                    clean_up_tokenization_spaces=True
                                    )
                end = time.time()
                print('Elapsed time is %f seconds for 20 samples, avearaged %f' % (end-start,(end-start)/20))

print("\n\nTC Supercon**************")
path_("./0_models_tc_supercon")  
print("OPTB88")
path_("./1_models_optb88vdw_bandgap")   
print("MBJ_BANDGAP")
path_("./2_models_mbj_bandgap")

# %%
# Nothing

# Fixed prompt

fourbit_models = [
        "unsloth/tinyllama-chat", #X
        "unsloth/mistral-7b-bnb-4bit", #X
        "unsloth/gemma-7b-bnb-4bit", #X
        "unsloth/llama-3-8b-bnb-4bit", #X 
]  # More models at https://huggingface.co/unsloth

def path_(path): 
        
        for model_idx, models in enumerate(fourbit_models):
                
                # LLM Models
                fourbit_model = fourbit_models[model_idx]   
                print("Models Name", fourbit_model)
                llm_model, llm_tokenizer = FastLanguageModel.from_pretrained(os.path.join(path, fourbit_model.split("/")[1])) 
                FastLanguageModel.for_inference(llm_model)  # Enable native 2x faster inference

                # Data Loading
            
                if path == "./0_models_tc_supercon":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "Tc_supercon" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                if path == "./1_models_optb88vdw_bandgap":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "optb88vdw_bandgap" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                if path == "./2_models_mbj_bandgap":
                        data_test = load_dataset("json", data_files="./data/alpaca_"+ "mbj_bandgap" +"_test.json", split="train") # #optb88vdw_bandgap  mbj_bandgap Tc_supercon
                
                data_test = data_test.add_column("prompt", eval_prompts(data_test))


                # LLM OUTPUT GENERATION
                
                start = time.time()

                sample = ""

                for idx in range(20):

                # for idx, prompt in enumerate(data_test["prompt"][:20]):

                        batch = llm_tokenizer(sample, return_tensors="pt")
                        batch = {k: v.cuda() for k, v in batch.items()}
                        generate_ids = llm_model.generate(
                                    **batch,
                                    do_sample=False,
                                    max_new_tokens=4096,
                                    pad_token_id=llm_tokenizer.eos_token_id,
                                    use_cache=True)

                        gen_strs = llm_tokenizer.batch_decode(
                                    generate_ids, 
                                    skip_special_tokens=True, 
                                    clean_up_tokenization_spaces=True
                                    )
                end = time.time()
                print('Elapsed time is %f seconds for 20 samples, avearaged %f' % (end-start,(end-start)/20))

print("\n\nTC Supercon**************")
path_("./0_models_tc_supercon")  
print("OPTB88")
path_("./1_models_optb88vdw_bandgap")   
print("MBJ_BANDGAP")
path_("./2_models_mbj_bandgap")
